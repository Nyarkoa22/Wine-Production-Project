# %% [markdown]
# # SENG207 PROGRAMMING PROJECT 1
# ## RED WINE PRODUCTION DATA ANALYSIS
# ### Index Number: 10968300
# ### Name: Nyarkoa Priscilla Yeboah
# ### Department: Food Process Engineering

# %%
import pandas as pan

# %%
results = pan.read_csv("data.csv")

# %%
results
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# # Checking for Null Values

# %%
results.isnull()
# Out:
#          ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     False          False             False        False           False
# 1     False          False             False        False           False
# 2     False          False             False        False           False
# 3     False          False             False        False           False
# 4     False          False             False        False           False
# ...     ...            ...               ...          ...             ...
# 1596  False          False             False        False           False
# 1597  False          False             False        False           False
# 1598  False          False             False        False           False
# 1599  False          False             False        False           False
# 1600  False          False             False        False           False
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# ...

# %%
results.isnull().sum()
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# # Replacing all null values with the mean of each column
# ---
# ---
# ### Null or missing values are a common occurrence in datasets which can pose a problem for data analysis and machine learning models. One way to handle missing values is to replace them with the mean of the corresponding feature.
#
# ## Reasons for using the mean method approach
# ---
# ### <span style ="color:blue">Retains the distribution</span>: Replacing missing values with the mean ensures that the overall distribution of the data is not significantly affected. This is important because it helps to preserve the statistical properties of the dataset, which can be important for downstream analysis.
#
# ### <span style ="color:blue">Simple and quick</span>: Replacing null values with the mean is a simple and quick method, especially when dealing with large datasets. This approach requires minimal computational resources, and it can be easily implemented in most programming languages and statistical software packages.
#
# ### <span style ="color:blue">Avoids bias</span>: When replacing null values with the mean, we are not introducing any significant bias in the dataset. For example, if we were to replace null values with the maximum or minimum value, this could introduce a bias in the dataset, which can negatively impact the analysis and predictions made by machine learning models.
#
# #### However, it's worth noting that replacing null values with the mean may not always be the best approach, depending on the specific characteristics of the dataset and the goals of the analysis. There are other methods available for handling missing values, such as using a regression model to predict the missing values or imputing values based on the median or mode.

# %% [markdown]
# # Checking for duplicates

# %%
results.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool

# %%
results.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # There is no duplicate in the dataset

# %% [markdown]
# # Statistical Inferences of the dataset

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
results.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1598.000000          1600.000000           1600.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047076            10.458487             32.977723
# ...

# %%
import numpy as num

# %%
import seaborn as seb

# %%
import matplotlib.pyplot as mplot

# %% [markdown]
# # Histrograms for the dataset

# %%
eliminating_ID = results.drop("ID", axis = 1)
eliminating_ID.hist(figsize=(20,20), ec="black", align="left", color="yellow")
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %% [markdown]
# # Showing the correlation of the results

# %%
eliminating_ID = results.drop("ID", axis = 1)
eliminating_ID.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255570     0.671061
# volatile acidity          -0.255570          1.000000    -0.552917
# citric acid                0.671061         -0.552917     1.000000
# residual sugar             0.114601          0.001877     0.143518
# chlorides                  0.093544          0.060826     0.204054
# free sulfur dioxide       -0.153049         -0.010592    -0.061269
# total sulfur dioxide      -0.113356          0.076249     0.036030
# density                    0.667912          0.022771     0.364309
# pH                        -0.682644          0.235306    -0.543019
# sulphates                  0.182303         -0.261364     0.312895
# alcohol                   -0.061859         -0.202672     0.109957
# quality                    0.124831         -0.390790     0.226906
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# # A line Graph for Quality in the results

# %%
EColumns = ["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides",
                "free sulfur dioxide", "total sulfur dioxide",
                "density", "pH", "sulphates", "alcohol"]

for columns in EColumns:
    mplot.title(f'Validity Graph for {columns}')
    seb.lineplot(x= "quality", y= columns, data = results)
    mplot.figure(figsize=(20,20))
                 
    mplot.show()

# %% [markdown]
# # Correlation of pH and the acids in the results

# %%
All_acids =  ["fixed acidity", "volatile acidity", "citric acid"]
for acid in All_acids:
    mplot.title(f'Correlation between pH and {acid}')
    seb.scatterplot(x=acid, y="pH", data=results, color=("green"))
    mplot.figure(figsize=(20,20))
    
    mplot.show()

# %%
mplot.title("Fixed Acidity Distribution")
seb.histplot(results["fixed acidity"], bins=25, color="yellow")
mplot.xlabel("Fixed Acidity")
mplot.ylabel("Frequency")

mplot.show()

# %% [markdown]
# #   Checking the values above and below the mean

# %%
mean_fixedAcidity = results["fixed acidity"].mean()
mean_compared = results["fixed acidity"] < mean_fixedAcidity

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Fixed Acidity values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_volatileAcidity = results["volatile acidity"].mean()
mean_compared = results["volatile acidity"] < mean_volatileAcidity

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Volatile Acidity values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_citricAcidity = results["citric acid"].mean()
mean_compared = results["citric acid"] < mean_citricAcidity

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Citric Acid values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_residualsugar = results["residual sugar"].mean()
mean_compared = results["residual sugar"] < mean_residualsugar

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Residual Sugar values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_chlorides = results["chlorides"].mean()
mean_compared = results["chlorides"] < mean_chlorides

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Chlorides values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_free_sulfur_dioxide = results["free sulfur dioxide"].mean()
mean_compared = results["free sulfur dioxide"] < mean_free_sulfur_dioxide

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Free Sulfur Dioxide values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_total_sulfur_dioxide = results["total sulfur dioxide"].mean()
mean_compared = results["total sulfur dioxide"] < mean_total_sulfur_dioxide

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Total Sulfur Dioxide values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_density = results["density"].mean()
mean_compared = results["density"] < mean_density

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Density values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_pH = results["pH"].mean()
mean_compared = results["pH"] < mean_pH

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of pH values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_sulphates = results["sulphates"].mean()
mean_compared = results["sulphates"] < mean_sulphates

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Sulphates values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_alcohol = results["alcohol"].mean()
mean_compared = results["alcohol"] < mean_alcohol

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Alcohol values and mean")
mplot.show()
mplot.savefig("image.png")

# %%
mean_quality = results["quality"].mean()
mean_compared = results["quality"] < mean_quality

mplot.pie(mean_compared.value_counts(), labels= ["Values < mean", "Values > mean"])
mplot.title("Comaprison of Quality values and mean")
mplot.show()
mplot.savefig("image.png")

# %% [markdown]
# # Checking for Hidden Inferences using Standard scores and Outliers
# ---
# ---
# ### Hidden inferences are conclusions or assumptions that are not explicitly stated or obvious, but are implied or suggested by the context or language used in a statement or text
#
# ## Standard scores
# ---
# ### Standard scores are a type of normalized score that indicates how many standard deviations an observation is above or below the mean of a distribution. They are used to compare an individual observation to the overall distribution of scores.
# ### The most common type of standard score is the z-score, which is calculated by subtracting the mean of a distribution from an individual observation and dividing the result by the standard deviation of the distribution. Z_scores help us identify outliers in a dataset and understand the variability of the data
#
# ## Outliers
# ---
# ### Outliers are data points that are significantly different from the other observations in a dataset. They can be unusually high or low values, or values that are far away from the central tendency of the data. Outliers can occur for various reasons, such as measurement errors, data entry errors, or genuinely rare or extreme events. However, outliers can also be a result of a systematic problem in the data, such as a biased sample or a data collection method that is not appropriate for the research question.
# ### One common method for identifying outliers is to use statistical tests, such as the z-score test or the Grubbs' test, to detect values that are significantly different from the others (box plot).
# ### They are identified using a threshold of 3 standard deviations or 3-sigma rule. It is important to note that the 3-sigma rule is just one way of identifying outliers and may not be appropriate for all datasets. Additionally, some datasets may not be normally distributed, in which case other methods for identifying outliers may be more appropriate

# %%
for column in results.columns:
    if column != "ID" :
     standard_scores = (results[column] - results[column].mean())/results[column].std()
     print(standard_scores)
    
     outliers = results[abs(standard_scores) > 3]
# Out:
# 0      -0.528652
# 1      -0.298772
# 2      -0.298772
# 3       1.655207
# 4      -0.528652
#           ...
# 1596   -1.390702
# 1597   -1.160822
# 1598   -1.390702
# 1599   -1.333232
# 1600   -0.643592
# Name: fixed acidity, Length: 1601, dtype: float64
# 0       0.962436
# 1       1.968129
# 2       1.297667
# 3      -1.384179
# 4       0.962436
#           ...
# 1596    0.124359
# 1597   -0.099128
# 1598    0.655141
# 1599   -1.216564
# 1600   -0.769590
# Name: volatile acidity, Length: 1601, dtype: float64
# 0      -1.392465
# 1      -1.392465
# 2      -1.187068
# 3       1.483097
# 4      -1.392465
#           ...
# 1596   -0.878972
# 1597   -0.724924
# 1598   -0.776273
# 1599    1.020953
# 1600    0.866905
# Name: citric acid, Length: 1601, dtype: float64
# 0      -0.453075
# 1       0.043683
# 2      -0.169213
# 3      -0.453075
# 4      -0.453075
#           ...
# 1596   -0.240179
# 1597   -0.169213
# 1598   -0.382109
# 1599    0.753337
# 1600    0.043683
# ...

# %%
outliers
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 459    460           11.6             0.580         0.66            2.20
# 517    518           10.4             0.610         0.49            2.10
# 690    691            7.4             1.185         0.00            4.25
# 832    833           10.4             0.440         0.42            1.50
# 899    900            8.3             1.020         0.02            3.40
# 1299  1300            7.6             1.580         0.00            2.10
# 1374  1375            6.8             0.815         0.00            1.20
# 1469  1470            7.3             0.980         0.05            2.10
# 1478  1479            7.1             0.875         0.05            5.70
# 1506  1507            6.7             0.760         0.02            1.80
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 459       0.074                 10.0                  47.0  1.00080  3.25
# ...

# %% [markdown]
# # Graph of Outliers of each columns

# %%
for column in outliers.columns:
    if column != 'ID':
        mplot.title(f'{column} outliers')
        mplot.xlabel('Values')
        
        seb.scatterplot(outliers[column])
        mplot.show()

# %% [markdown]
# # Using pairplot to show hidden inferences

# %%
seb.pairplot(results, hue= "quality", vars=["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides"], palette= "viridis")

# %% [markdown]
# # The heatmap of the dataset

# %%
correlation_mat = results.corr()
seb.heatmap(correlation_mat, annot=True, cmap="coolwarm")
mplot.figure(figsize=(20,20))

mplot.show()

# %% [markdown]
# # Data Analysis Performed on Red Wine Production

# %% [markdown]
# # THE END

# %% [markdown]
# # <span style ="color:blue">THANK YOU</span>
